# %% [markdown]
# # 基隆社福地圖
#
# - [HackFoldr/基隆社福地圖](http://pro.odtw.org/2017ODProjects/https%253A%252F%252Fhackmd.io%252Fs%252FB1A4KFznW)
# - [Github/KL-SocialWelfare](https://github.com/DATA-GOV-TW/TWGOV-KL-SocialWelfare)
# - [基隆社會處](http://social.klcg.gov.tw/)
# - [基隆市開放資料](https://data.gov.tw/datasets/search?qs=dtid:22001+%E5%9F%BA%E9%9A%86)
#
# ## ToDo
# 1. data.gov.tw node to datapackage
# 2. 社會處網站 info to datasets
# 3. 社福地圖
# 4. 依照族群對像，客製服務

# %%
# encoding: utf-8
# 基隆市資料清單
nodeList = [10340,10344,11093,11257,11271,14864,14869,15152,15293,23198,23201,
            27495,28983,28987,28988,28993,28994,28995,29021,31159,31251,31818,
            31819,31848,31849,31850,31858,31862,36947,38824,42338,42578,44662,
            44663,44664,44665,45581,45624,45672,45693,45709,45710,45711,45714,
            45718,45719,45720,45721,45722,45723,45724,45725,45726,45727,45728,
            45729,45730,45732,45745,45749,45750,45751,45756,45757,45758,45811,
            46439,46441,46442,46444,46445,46446,46447,46448,48126,48143,48205,
            48887,49016,49302,49303,49520,49565,49567,49569,49570,49803,49974,
            49979,49980,49981,49983,52731,53055,53080,54326,54340,54554,54969,
            54970,54972,55004,55072,55242,55245,55257,55258,55259,55261 ]

# %%
# encoding: utf-8
# 2017.10.06
# Data.gov.tw / node to DataPackage format
#
# 資料集名稱 - title
# 資料集描述 - description
# 主要欄位說明_0 - schema
# ---------------
# 資料資源 - resource
# 主要欄位說明 - res_schema
# 檔案格式 - res_format
# 編碼 - res_encoding
# 資料量 - res_size
# 資源網址 - res_url
# 資源描述 - res_description
# 資料資源更新時間 - res_last_updated
# ---------------
# 提供機關 - publisher
# 提供機關聯絡人 - publisher_contact
# 更新頻率 - update_frq
# 授權方式 - license
# 計費方式 - cost
# 上架日期 - created_date
# 資料集類型 - data_type
# 詮釋資料更新時間 - last_updated
# 關鍵字 - keywords
# 主題分類 - categories
# 服務分類 - services_cat
# 備註 - notes
# 統計 - stats

labelOrg = ['資料集名稱', '資料集描述', '主要欄位說明_0', '資料資源', '主要欄位說明', '檔案格式',
            '編碼', '資料量', '資源網址', '資源描述', '資料資源更新時間', '提供機關', '提供機關聯絡人',
            '更新頻率', '授權方式', '計費方式', '上架日期', '資料集類型', '詮釋資料更新時間',
            '關鍵字', '主題分類', '服務分類', '備註', '統計']

labelDpg = ['title', 'description', ]

print(labelCont)

# %%
# get time now()
from datetime import datetime, tzinfo
print(datetime.now())

# get dir files List
from os import walk

f = []
for (dirpath, dirnames, filenames) in walk('f:\\DataSet\\@地方\\基隆市\\Datasets\\'):
    f.extend(filenames)
    break
f = f[:-2]
# print(f)
dirList = {}
itemCount = int(len(f) / 2)
for i in range(0, itemCount):
    print(f[i*2])
    dirList[f[i*2][:5]] = [f[i*2], f[i*2+1]]
print(dirList['45751'])

# %%
# encoding: utf-8

# 2017.10.06
# node to datapackage
#


# import pprint
import requests
from bs4 import BeautifulSoup
import json
from datetime import datetime, tzinfo
from time import sleep


nodeList = [10340,10344,11093,11257,11271,14864,14869,15152,15293,23198,23201,
            27495,28983,28987,28988,28993,28994,28995,29021,31159,31251,31818,
            31819,31848,31849,31850,31858,31862,36947,38824,42338,42578,44662,
            44663,44664,44665,45581,45624,45672,45693,45709,45710,45711,45714,
            45718,45719,45720,45721,45722,45723,45724,45725,45726,45727,45728,
            45729,45730,45732,45745,45749,45750,45751,45756,45757,45758,45811,
            46439,46441,46442,46444,46445,46446,46447,46448,48126,48143,48205]

for k in nodeList :
    # node = xxxxx / http://data.gov.tw/node/xxxxx
    nodeNum = str(k)
    node_url = "http://data.gov.tw/node/" + nodeNum
    baseURL = 'f:\\DataSet\\@地方\\基隆市\\Datasets\\'

    r = requests.get(node_url)
    r = BeautifulSoup(r.content.decode('utf-8'), 'html.parser')


    # get resources Count
    resCount = int(len(r.find_all('a', class_ = 'dgresource')) /  2)
    resCount1 = resCount

    # get keywords count
    keyCount = r.find_all('div', class_ = 'tag-wrapper')

    # get all field label
    nodeContent = r.find_all("div", class_ = "field-label")
    nodeTitle = r.select("h1.node-title")

    # set up field label list
    labelCont = []

    # remove beginning ':' and trim space
    for i in nodeContent:
        labelCont.append(i.get_text().strip().replace(':',''))

    # defaut resCount = 1, so remove 1 = remove default one
    resCount -= 1
    posAdd = 11

    # if resCount > 1 - add new field label and rename field label + count number
    while resCount != 0:
        labelCont.insert(posAdd, '資料資源_' + str(resCount))
        for i in range(1, 8) :
            labelCont[i+posAdd] = labelCont[i+posAdd] + '_' + str(resCount)
        resCount -= 1
        posAdd += 8

    # if keyCount != 0 
    keyPos = [i for i,x in enumerate(labelCont) if x == '關鍵字']
    keyPos = int(keyPos[0])
    if len(keyCount) != 0 :
        for i in range(0, len(keyCount)):
            labelCont.insert(keyPos+1, '關鍵字_' + str(i))

    labelCont.append('統計')
    # pp = pprint.PrettyPrinter(indent=4)
    # print(labelCont)
    # print('=====================================================================')

    nodeContent = r.find_all("div", class_ = "field-item")
    labelCont[2] = '主要欄位說明_0'
    jData = {}
    jTitle = r.title.get_text().replace(' | 政府資料開放平臺', '')
    jData['title'] = jTitle
    jData['node'] = str(k)
    jData['created'] = str(datetime.now())[:-7]
    
    for i in range(1, len(labelCont)):
        textCont = nodeContent[i].get_text()
        textCont.replace('\r\n', '')
        if '資料資源' in labelCont[i] : continue
        # print('{:2d} - {} : {}'.format(i, labelCont[i], textCont))
        jData[labelCont[i]] = textCont.strip('\n\t\r')

# 新增欄位
# 資源數量 : resCount1
# 關鍵字數量 : keyCount[]
# 備註拆解 + 授權說明網址
    jData['resource'] = resCount1
    jData['keywords'] = int(len(keyCount))
    if '備註' not in jData.keys() :
        jData['備註'] = ''
    jData['授權說明網址'] = ''
    if '授權說明網址' in jData['備註'] :
        jData['授權說明網址'] = jData['備註'][8:]


    # print('=====================================================================')
    # print(jData)


    jFile = baseURL + nodeNum + ' - ' + jData['提供機關'] + '.' + jTitle + '.json'
    print(jFile)
    f = open(jFile, 'w', encoding = 'utf-8')
    json.dump(jData, f, ensure_ascii=False, indent=4)
    f.close()
    
    sleep(1)
print("----------------------------- end -----------------------------------")

# %%
# encoding: utf-8
# data quality check
# get answer from http://quality.data.gov.tw/
# /dq_event.php?nid=xxxx
# ex : http://quality.data.gov.tw/dq_event.php?nid=31111
#
# good : 55521
# wrong : 55523
# bad : 45709


import requests
from bs4 import BeautifulSoup
import json
import pprint
from time import sleep

# 基隆市資料清單
nodeList = [10340,10344]

baseURL = 'f:\\DataSet\\@地方\\基隆市\\Datasets\\'
pp = pprint.PrettyPrinter(indent=4)

print('=====================================================================')

for k in nodeList:
    nodeNum = str(k)
    dq_url = "http://quality.data.gov.tw/dq_event.php?nid=" + nodeNum

    r = requests.get(dq_url)
    f = open(baseURL + nodeNum + ' - DQ.json', 'w', encoding='utf-8')
    print(baseURL + nodeNum + ' - DQ.json')


    rContent = r.text[1:].strip() # remove first ':' character and space

    if 'event: done' in rContent :
        rIndex = rContent.index('done')
        rResult = rContent[rIndex+21:-1]
        jData = json.JSONDecoder().decode(rResult)
        
        json.dump(jData, f, ensure_ascii=False, indent=4)
        f.close()

    else :
        if 'event: nop' in rContent :
            rResult = '{ "status" : "wrong node" }'
        else :
            rResult = "non 'event : done'\n" + rContent
        pp.pprint(rContent.split('\n'))
        f.write(rResult)
        f.close()

    if k % 10 == 0 :
        sleep(1)
    
print("----------------------------- end -----------------------------------")

# %%
# encoding: utf-8
# 2017.10.07
#
# Make datapackage + folder
# Folder - nodeNumber - Publisher - Title
# Files 
#     - datapackage.nodeNumber.json
#     - resources.nodeNumber.json
#     - resources.files
#
#
